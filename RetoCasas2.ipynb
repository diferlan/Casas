# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import math
from scipy.stats import chi2_contingency

# %%
def fit_train_eval(pipeline,df):
  X_train, X_test, y_train, y_test = train_test_split(df.drop('SalePrice',axis=1),df['SalePrice'],train_size=0.3,random_state=6)
  pipeline.fit(X_train, y_train)
  y_pred = pipeline.predict(X_train)
  return math.sqrt(mean_squared_error(np.log(y_train), np.log(y_pred)))

# %%
def test_kaggle():
  #Read
  test = pd.read_csv('/content/drive/MyDrive/7 Semestre/house-prices-advanced-regression-techniques/test.csv')
  #Elimate ID
  X_ = test.drop(['Id'],axis=1)
  #Fill nans
  media = X_[['YearBuilt', 'YearRemodAdd','GarageYrBlt','YrSold']].mean()
  X_[['YearBuilt', 'YearRemodAdd','GarageYrBlt','YrSold']].fillna(media)
  X_.fillna(0,inplace=True)
  #Predict
  results = pipeline.predict(X_)
  csv =pd.DataFrame({'Id':test['Id'], 'SalePrice': results})
  csv.to_csv('prediction2.csv',index=False)
  return

# %%
df = pd.read_csv('/content/drive/MyDrive/7 Semestre/house-prices-advanced-regression-techniques/train_clean.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-bc5a4cc5eb24> in <module>
# ----> 1 df = pd.read_csv('/content/drive/MyDrive/7 Semestre/house-prices-advanced-regression-techniques/train_clean.csv')
#
# ...

# %%
cols = {}
for col in df.columns:
  for col2 in df.columns:
    if col != col2 :
        temp_table = pd.crosstab(df[col], df[col2])
        chi2, p, _, _ = chi2_contingency(temp_table)
        if p < 0.05:
          cols[col] = col2

# %%
cols = {key: valor for key, valor in cols.items() if not key.startswith('SalePrice')}

# %%
cols = {key: valor for key, valor in cols.items() if not valor.startswith('SalePrice')}

# %%
cols
# Out:
# {'MSSubClass': 'SaleCondition',
#  'Alley': 'SaleCondition',
#  'LandContour': 'SaleCondition',
#  'Utilities': 'SaleCondition',
#  'LandSlope': 'MiscVal',
#  'Condition1': 'MiscFeature',
#  'Condition2': 'MiscVal',
#  'BldgType': 'SaleCondition',
#  'HouseStyle': 'SaleCondition',
#  'YearBuilt': 'SaleCondition',
#  'YearRemodAdd': 'SaleCondition',
#  'RoofStyle': 'MiscVal',
#  'RoofMatl': 'PoolQC',
#  'Exterior1st': 'SaleCondition',
#  'Exterior2nd': 'SaleCondition',
#  'ExterCond': 'SaleCondition',
#  'BsmtFinType1': 'SaleCondition',
#  'BsmtFinSF1': 'MiscFeature',
#  'BsmtFinType2': 'SaleCondition',
#  'BsmtFinSF2': 'SaleType',
#  'HeatingQC': 'SaleCondition',
#  'LowQualFinSF': 'MiscVal',
#  'KitchenAbvGr': 'SaleCondition',
#  'Functional': 'MiscVal',
#  'GarageType': 'SaleCondition',
#  'GarageYrBlt': 'SaleCondition',
#  'GarageCond': 'MiscVal',
#  'PavedDrive': 'SaleCondition',
#  'WoodDeckSF': 'SaleType',
#  'EnclosedPorch': 'MiscVal',
#  '3SsnPorch': 'MoSold',
# ...

# %%
quitar = ['SaleCondition']

# %%
numeric_cols = df.select_dtypes(include='number').columns
categ_cols = df.select_dtypes(include='object').columns

# %%
#PREPROCESAMIENTO
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
#Escalamiento para las variables numericas
#Dummies para las variables categoricas
preprocessing = ColumnTransformer(transformers=[
        ('num', StandardScaler(), numeric_cols[:-1]),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categ_cols)
    ])

from sklearn.ensemble import GradientBoostingRegressor
modelo = GradientBoostingRegressor() #0.018

from sklearn.pipeline import Pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessing),
                           ('model', modelo)])

# %%
df.describe()
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:4527: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:4527: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:4527: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:4527: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:4527: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:4527: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# ...

# %%
fit_train_eval(pipeline,df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-ff12973256b9> in <cell line: 1>()
# ----> 1 fit_train_eval(pipeline,df)
#
# <ipython-input-27-e7954fbb935d> in fit_train_eval(pipeline, df)
#       1 def fit_train_eval(pipeline,df):
#       2   X_train, X_test, y_train, y_test = train_test_split(df.drop('SalePrice',axis=1),df['SalePrice'],train_size=0.3,random_state=6)
# ----> 3   pipeline.fit(X_train, y_train)
#       4   y_pred = pipeline.predict(X_train)
#       5   return math.sqrt(mean_squared_error(np.log(y_train), np.log(y_pred)))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     399         """
#     400         fit_params_steps = self._check_fit_params(**fit_params)
# --> 401         Xt = self._fit(X, y, **fit_params_steps)
# ...

# %%
joblib.dump(pipeline,'pipeline_houses_final.joblib')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0ffbdc50ef37> in <module>
# ----> 1 joblib.dump(pipeline,'pipeline_houses_final.joblib')
#
# NameError: name 'pipeline' is not defined
